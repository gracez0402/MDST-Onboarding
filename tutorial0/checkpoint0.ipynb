# %% [markdown]
# # Checkpoint 0
# ## Do not remove comments that start with: "# @@@" (Those are question tags)

# %% [markdown]
# These exercises are a mix of Python and Pandas practice. Most should be no more than a few lines of code!
#
# Do not remove comments that start with: "# @@@" (Those are question tags)

# %%
# @@@ Question 1: Here is a python list, initialize another list called b with the same values as a.

a = [1, 2, 3, 4, 5, 6]
b = a.copy()
print(b)

# %%
# @@@ Question 2: get a list containing the last 3 elements of b 
# Yes, you can just type out [4, 5, 6] but we really want to see you demonstrate you know how to use list slicing in Python
b[-3:]

# %%
# @@@ Question 3: Create a list of numbers from 1 to 20
[x for x in range(1,21)]

# %%
# @@@ Question 4: now get a list with only the even numbers between 1 and 100
[x for x in range(1,101) if x%2 == 0]

# %%
# @@@ Question 5: write a function that takes two numbers as arguments
# and returns the first number divided by the second
def number_division(x,y):
    return x/y

# %%
# @@@ Queston 6: fizzbuzz
# you will need to use both iteration and control flow 
# go through all numbers from 1 to 30 in order
# if the number is a multiple of 3, print fizz
# if the number is a multiple of 5, print buzz
# if the number is a multiple of 3 and 5, print fizzbuzz and NOTHING ELSE
# if the number is neither a multiple of 3 nor a multiple of 5, print the number
for number in range(1,31):
    if number%3 == 0 and number%5 == 0:
        print("fizzbuzz")
    elif number%3 == 0:
        print("fizz")
    elif number%5 == 0:
        print("buzz")
    else:
        print(number)

# %%
# @@@ Question 7: create a dictionary that reflects the following menu pricing (taken from Ahmo's)
# Gyro: $9 
# Burger: $9
# Greek Salad: $8
# Philly Steak: $10
price = {"Gyro":9, "Burger":9, "Greek Salad":8, "Philly Steak":10}

# %%
# @@@ Question 8: load in the "starbucks.csv" dataset
# refer to how we read the cereal.csv dataset in the tutorial
import pandas as pd

# %%
starbucks = pd.read_csv("starbucks.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 starbucks = pd.read_csv("starbucks.csv")
#
# File ~/Desktop/mdst/MDST-Onboarding/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:872, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     860 kwds_defaults = _refine_defaults_read(
#     861     dialect,
#     862     delimiter,
#    (...)    868     dtype_backend=dtype_backend,
#     869 )
#     870 kwds.update(kwds_defaults)
# --> 872 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/mdst/MDST-Onboarding/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/Desktop/mdst/MDST-Onboarding/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1643, in TextFileReader.__init__(self, f, engine, **kwds)
#    1640     self.options["has_index_names"] = kwds["has_index_names"]
#    1642 self.handles: IOHandles | None = None
# -> 1643 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/mdst/MDST-Onboarding/venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1907, in TextFileReader._make_engine(self, f, engine)
#    1905     if "b" not in mode:
#    1906         mode += "b"
# -> 1907 self.handles = get_handle(
#    1908     f,
#    1909     mode,
#    1910     encoding=self.options.get("encoding", None),
#    1911     compression=self.options.get("compression", None),
#    1912     memory_map=self.options.get("memory_map", False),
#    1913     is_text=is_text,
#    1914     errors=self.options.get("encoding_errors", "strict"),
#    1915     storage_options=self.options.get("storage_options", None),
#    1916 )
#    1917 assert self.handles is not None
#    1918 f = self.handles.handle
#
# File ~/Desktop/mdst/MDST-Onboarding/venv/lib/python3.11/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'starbucks.csv'

# %%
# @@@ Question 9: select all rows with more than and including 400 calories
starbucks[starbucks["Calories"] >= 400]

# %%
# @@@ Question 10: select all rows whose vitamin c content is higher than the iron content
starbucks[starbucks["Vitamin C (% DV)"] > starbucks["Iron (% DV)"]]

# %%
# @@@ Question 11: create a new column containing the caffeine per calories of each drink
starbucks["Caffeine per Calorie"] = starbucks["Caffeine (mg)"] / starbucks["Calories"]
starbucks

# %%
# @@@ Question 12: what is the average calorie across all items?
starbucks["Calories"].mean()

# %%
# @@@ Question 13: how many different categories of beverages are there?
starbucks["Beverage_category"].nunique()

# %%
# @@@ Question 14: what is the average # calories for each beverage category?
starbucks.groupby("Beverage_category")["Calories"].mean()
