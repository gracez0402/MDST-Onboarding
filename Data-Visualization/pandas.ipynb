# %% [markdown]
# # Data Visualization in Pandas

# %% [markdown]
# In this tutorial, we will show some samples of plotting functionality built into `pandas`. These functions are good for getting a quick visual for rough understanding of the data.
#
# For a more complete discussion, see this [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html).

# %%
import pandas as pd
df = pd.read_csv('../data/cereal.csv')

# %% [markdown]
# ## One Variable, Continuous
#
# When dealing with continuous data, it is important to understand its distribution.
#
# `describe()` is a good start but sometimes it fails to tell full story.

# %%
# We can use a histogram (plot.hist)
# Let's demonstrate it with the sodium column

df["sodium"].plot.hist(edgecolor='black', alpha=0.8, title="Sodium Content Distrbution")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 # We can use a histogram (plot.hist)
#       2 # Let's demonstrate it with the sodium column
#       3
# ----> 4 df["sodium"].plot.hist(edgecolor='black', alpha=0.8, title="Sodium Content Distrbution")
#
# File ~/Desktop/mdst/MDST-Onboarding/venv/lib/python3.11/site-packages/pandas/plotting/_core.py:1694, in PlotAccessor.hist(self, by, bins, **kwargs)
#    1639 def hist(
#    1640     self, by: IndexLabel | None = None, bins: int = 10, **kwargs
#    1641 ) -> PlotAccessor:
#    1642     """
#    1643     Draw one histogram of the DataFrame's columns.
#    1644
#    (...)   1692         >>> ax = df.plot.hist(column=["age"], by="gender", figsize=(10, 8))
#    1693     """
# -> 1694     return self(kind="hist", by=by, bins=bins, **kwargs)
#
# File ~/Desktop/mdst/MDST-Onboarding/venv/lib/python3.11/site-packages/pandas/plotting/_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File ~/Desktop/mdst/MDST-Onboarding/venv/lib/python3.11/site-packages/pandas/plotting/_core.py:2251, in _get_plot_backend(backend)
#    2248 if backend_str in _backends:
#    2249     return _backends[backend_str]
# -> 2251 module = _load_backend(backend_str)
#    2252 _backends[backend_str] = module
#    2253 return module
#
# File ~/Desktop/mdst/MDST-Onboarding/venv/lib/python3.11/site-packages/pandas/plotting/_core.py:2183, in _load_backend(backend)
#    2181         module = importlib.import_module("pandas.plotting._matplotlib")
#    2182     except ImportError:
# -> 2183         raise ImportError(
#    2184             "matplotlib is required for plotting when the "
#    2185             'default backend "matplotlib" is selected.'
#    2186         ) from None
#    2187     return module
#    2189 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %% [markdown]
# Three arguments are supplied to the plot function to make the output looks nicer. Playing around with all the arguments as documented [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.hist.html#pandas.Series.plot.hist) and [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot) is by far the best way to learn visualization skills.

# %%
# It feels a bit weird to visualize continuous data with discrete bins, doesn't it
# Density plots address this problem (plot.kde)
# We will demonstrate it with the vitamins column
df["vitamins"].plot.kde(title="Vitamins Content Distribution")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # It feels a bit weird to visualize continuous data with discrete bins, doesn't it
#       2 # Density plots address this problem (plot.kde)
#       3 # We will demonstrate it with the vitamins column
# ----> 4 df["vitamins"].plot.kde(title="Vitamins Content Distribution")
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Two Variables, Both Discrete

# %%
# We will use bar graphs to visualize how many differnet cereals each manufacturer make (plot.bar)
# First, let's group by manufacturer and count their cereals

num_by_mfr = df.groupby("mfr")["name"].count()
num_by_mfr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # We will use bar graphs to visualize how many differnet cereals each manufacturer make (plot.bar)
#       2 # First, let's group by manufacturer and count their cereals
#       3
# ----> 4 num_by_mfr = df.groupby("mfr")["name"].count()
#       5 num_by_mfr
#
# NameError: name 'df' is not defined

# %%
num_by_mfr.plot.bar(title="Number of Cereals Each Manufacturer Makes", grid="True", rot=0)

# %% [markdown]
# ## Two Variables, Both Continuous

# %%
# Scatterplots are the most suitable for these data (plot.scatter) 
# Let's look at the relationship between sugar content and rating
df.plot.scatter(x="sugars", y="rating", title="Rating vs Sugar Content")
